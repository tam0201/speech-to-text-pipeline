# %%
import ktrain
from omegaconf import OmegaConf
from ktrain import text as ktrain_text
predictor = ktrain.load_predictor('/home/tam/Desktop/speech-to-text-pipeline/soap_bert_classifier.h5')
predictor = ktrain.get_predictor(predictor.model, predictor.preproc)
predictor.predict("I'm not suicidal.", "Sometimes I cut myself to feel the pain and release it in the past I cut too deep but got stitched up.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/anaconda3/envs/speech/lib/python3.11/site-packages/ktrain/text/preprocessor.py:872, in TransformersPreprocessor.__init__(self, model_name, maxlen, max_features, class_names, classes, lang, ngram_range, multilabel)
#     869 try:
#     870     self.use_token_type_ids = (
#     871         "token_type_ids"
# --> 872         in self.model_type.from_pretrained(
#     873             self.model_name
#     874         ).call.__code__.co_varnames
#     875     )
#     876 except:
#
# File ~/anaconda3/envs/speech/lib/python3.11/site-packages/transformers/utils/import_utils.py:1304, in DummyObject.__getattribute__(cls, key)
#    1303     return super().__getattribute__(key)
# -> 1304 requires_backends(cls, cls._backends)
#
# ...

# %%
# !pip install ktrain omegaconf tensorflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 440.9 kB/s eta 0:00:00 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 1.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 997.1 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.3/475.3 MB 2.0 MB/s eta 0:00:0000:0100:02m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 1.2 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 4.9 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 7.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 7.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 1.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 8.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 1.7 MB/s eta 0:00:0000:01
# ...
